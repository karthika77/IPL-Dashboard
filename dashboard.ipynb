# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install dash
# Out:
# Requirement already satisfied: numpy in c:\users\elcot\downloads\anaconda\lib\site-packages (1.21.5)
# Requirement already satisfied: pandas in c:\users\elcot\downloads\anaconda\lib\site-packages (1.4.4)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\elcot\downloads\anaconda\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\elcot\downloads\anaconda\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\elcot\downloads\anaconda\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\elcot\downloads\anaconda\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\elcot\downloads\anaconda\lib\site-packages (3.5.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\elcot\downloads\anaconda\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\elcot\downloads\anaconda\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\elcot\downloads\anaconda\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\elcot\downloads\anaconda\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\elcot\downloads\anaconda\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\elcot\downloads\anaconda\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\elcot\downloads\anaconda\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\elcot\downloads\anaconda\lib\site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: six>=1.5 in c:\users\elcot\downloads\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in c:\users\elcot\downloads\anaconda\lib\site-packages (0.11.2)
# Requirement already satisfied: scipy>=1.0 in c:\users\elcot\downloads\anaconda\lib\site-packages (from seaborn) (1.9.1)
# Requirement already satisfied: numpy>=1.15 in c:\users\elcot\downloads\anaconda\lib\site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\elcot\downloads\anaconda\lib\site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: pandas>=0.23 in c:\users\elcot\downloads\anaconda\lib\site-packages (from seaborn) (1.4.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\elcot\downloads\anaconda\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\elcot\downloads\anaconda\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\elcot\downloads\anaconda\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\elcot\downloads\anaconda\lib\site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\elcot\downloads\anaconda\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\elcot\downloads\anaconda\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\elcot\downloads\anaconda\lib\site-packages (from matplotlib>=2.2->seaborn) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\elcot\downloads\anaconda\lib\site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\elcot\downloads\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: dash in c:\users\elcot\downloads\anaconda\lib\site-packages (2.9.1)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\elcot\downloads\anaconda\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\elcot\downloads\anaconda\lib\site-packages (from dash) (5.9.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\elcot\downloads\anaconda\lib\site-packages (from dash) (1.1.2)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\elcot\downloads\anaconda\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\elcot\downloads\anaconda\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\elcot\downloads\anaconda\lib\site-packages (from Flask>=1.0.4->dash) (2.0.3)
# Requirement already satisfied: click>=5.1 in c:\users\elcot\downloads\anaconda\lib\site-packages (from Flask>=1.0.4->dash) (8.0.4)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\elcot\downloads\anaconda\lib\site-packages (from Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\elcot\downloads\anaconda\lib\site-packages (from Flask>=1.0.4->dash) (2.11.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\elcot\downloads\anaconda\lib\site-packages (from plotly>=5.0.0->dash) (8.0.1)
# Requirement already satisfied: colorama in c:\users\elcot\downloads\anaconda\lib\site-packages (from click>=5.1->Flask>=1.0.4->dash) (0.4.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\elcot\downloads\anaconda\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash) (2.0.1)

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output

# Load IPL dataset
df = pd.read_csv('matches.csv')

# Create the app
app = dash.Dash(__name__)

# Define the layout
app.layout = html.Div([
    html.H1('IPL Dashboard'),

    # Scatter plot
    dcc.Graph(id='scatterplot',
              figure={
                  'data': [
                      go.Scatter(x=df['toss_winner'],
                                 y=df['winner'],
                                 mode='markers')
                  ],
                  'layout': {
                      'title': 'Toss winner vs. Match winner',
                      'xaxis': {'title': 'Toss winner'},
                      'yaxis': {'title': 'Match winner'}
                  }
              }),

    # Box plot
    dcc.Graph(id='boxplot',
              figure={
                  'data': [
                      go.Box(y=df['win_by_runs'], name='Win by runs'),
                      go.Box(y=df['win_by_wickets'], name='Win by wickets')
                  ],
                  'layout': {
                      'title': 'Distribution of wins',
                      'yaxis': {'title': 'Number of runs/wickets'}
                  }
              }),

    # Histogram
    dcc.Graph(id='histogram',
              figure={
                  'data': [
                      go.Histogram(x=df['toss_decision'], nbinsx=10)
                  ],
                  'layout': {
                      'title': 'Toss decision distribution',
                      'xaxis': {'title': 'Toss decision'}
                  }
              }),

    # Mosaic plot
    dcc.Graph(id='mosaicplot',
              figure={
                  'data': [
                      go.Heatmap(x=df['winner'],
                                 y=df['city'],
                                 z=df['id'],
                                 colorscale='YlOrRd')
                  ],
                  'layout': {
                      'title': 'Winners by city and match ID',
                      'xaxis': {'title': 'Match winner'},
                      'yaxis': {'title': 'City'}
                  }
              }),

    # Bar chart
    dcc.Graph(id='barchart',
              figure=px.bar(df, x='winner', y='win_by_wickets', color='Season',
                            title='Player of the match by winner and season',
                            labels={'winner': 'Match winner', 'player_of_match': 'Player of the match',
                                    'Season': 'Season'})
              )
])

if __name__ == '__main__':
    app.run_server(port=8050)
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_996\3182141439.py:5: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_996\3182141439.py:6: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [26/Mar/2023 23:07:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Mar/2023 23:07:02] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Mar/2023 23:07:02] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Mar/2023 23:07:03] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Mar/2023 23:07:03] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
